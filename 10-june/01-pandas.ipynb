# %% [markdown]
# # Pandas
#
# ## Series
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
import pandasai as pdAI

# %%
sdf = pdAI.SmartDataframe(df)

sdf.chat("Plot a line chart of the Median wage of South East Asian countries from 1990 to 2020")
# Out:
# 'c:/Users/Clark/Desktop/bbcs-2024/10-june/exports/charts/temp_chart.png'

# %%
sdf.last_code_generated
# Out:
# "data = {'Country': ['Vietnam', 'Malaysia', 'Singapore'], '1990': [1300, 1000, 1500], '1995': [1800, 1300, 1500], '2000': [1500, 2000, 1100], '2005': [2200, 1600, 1200], '2010': [1300, 1800, 2000], '2015': [2200, 2000, 2600], '2020': [2600, 1500, 2800], 'Median': [1200.0, 1900.0, 2000.0]}\ndf = dfs[0]\nplt.figure(figsize=(10, 6))\nfor country in df['Country']:\n    plt.plot(df.columns[1:-1], df.loc[df['Country'] == country, '1990':'2020'].values.flatten(), marker='o', label=country)\nplt.xlabel('Year')\nplt.ylabel('Median Wage')\nplt.title('Median Wage of South East Asian Countries (1990-2020)')\nplt.legend()\nplt.grid(True)\nplt.xticks(rotation=45)\nplt.savefig('c:/Users/Clark/Desktop/bbcs-2024/10-june/exports/charts/temp_chart.png')\nresult = {'type': 'plot', 'value': 'c:/Users/Clark/Desktop/bbcs-2024/10-june/exports/charts/temp_chart.png'}"

# %%
sdf.chat("Using the dataset on median wages, create a linear regression model of Singapore's median wage.")
# Out:
# Intercept: -98435.7142857143
# Coefficient: 50.00000000000001
# "Singapore's linear regression model: Median Wage = -98435.7142857143 + 50.00000000000001 * Year"

# %%
sdf.chat("Using this equation, plot a graph of Singapore's median wage from 1990 to 2050")
# Out:
# 'c:/Users/Clark/Desktop/bbcs-2024/10-june/exports/charts/temp_chart.png'

# %%
sdf.chat("Create a line plot of weekly COVID-19 infections and deaths in the United States in the year 2021")
# Out:
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 310, in run
#     ).run(input)
#       ^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# ...
