# %%
import pandasai as pdAI
import os

os.environ['PANDASAI_API_KEY'] = '$2a$10$yEy7FF7gteY9FEljMo2z3Oxtgx2ntttSNv5adfxmlfJr5EBFQhyDC'

# %% [markdown]
# **Exercise: With the sales_data_sample.csv, find the customer who bought the most products with Agent as an assistant. You may require multiple queries in order to achieve this**

# %%
import pandas as pd

sales = pd.read_csv('sales_data_sample.csv')

# %%
agent = pdAI.Agent([sales])

# %%
agent.chat('Sort the dataset by the quantity ordered')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 751         10409                6     100.00                2    785.64
# 1287        10407                6      90.19                3    541.14
# 907         10423               10      88.14                1    881.40
# 315         10419               10     100.00               11   1092.20
# 2507        10401               11     100.00                8   1135.31
# ...           ...              ...        ...              ...       ...
# 1995        10405               76     100.00                3  11739.70
# 598         10407               76     100.00                2  14082.80
# 2689        10401               77      92.00                9   7084.00
# 2586        10401               85      88.75               10   7543.75
# 418         10405               97      93.28                5   9048.16
#
#            ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
agent.chat('Who is customer with the most orders?')
# Out:
# 'The customer with the most orders is Euro Shopping Channel.'

# %%
agent.chat('What is the contact name of the customer with the most orders?')
# Out:
# 'Diego Freyre'

# %%
agent.chat('How much did the customer with the most orders spend?')
# Out:
# 912294.11
